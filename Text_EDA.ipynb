# %% [markdown]
# <a href="https://colab.research.google.com/github/alicevangomez/EDA/blob/main/Text_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Exploratory Data Analysis on Text Data**

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import urllib

# %% [markdown]
# ### **Nube de palabras (World Cloud)**

# %%
#1. Cargar el texto
text = urllib.request.urlopen('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/alice_novel.txt').read().decode("utf-8")

#2. Crear el conjunto de stopwords
stopwords_set = set(STOPWORDS) #the function set to remove any redundant stopwords(palabras vacías)
stopwords_set.add('said') # Agregar palabras extra que no queremos en la nube

#3. Crear el objeto WordCloud
wc = WordCloud(stopwords = stopwords_set)

#4. Generar la nube con el texto
wc.generate(text)

#5. Mostrar la nube
fig = plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### **Nube de palabras con máscara de imagen (Image Mask Word Cloud)**

# %%
#1. Cargar el texto
text = urllib.request.urlopen('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/alice_novel.txt').read().decode("utf-8")

#2. Cargar la imagen como máscara (debe estar en blanco y negro o escala de grises)
mask_image = np.array(Image.open(urllib.request.urlopen('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%204/images/alice_mask.png')))

#3. Crear el conjunto de stopwords
stopwords_set = set(STOPWORDS) #the function set to remove any redundant stopwords(palabras vacías)
stopwords_set.add('said') # Agregar palabras extra que no queremos en la nube

# 4. Crear el objeto WordCloud
wc = WordCloud(background_color='white',
               max_words=2000,
               mask=alice_mask,
               stopwords=stopwords_set,
               contour_width=1,
               contour_color='white')

# 5. Generar la nube con el texto
wc.generate(text)

# 6. Mostrar la nube
fig = plt.figure(figsize=(13, 13))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
